# %% [markdown]
# <a href="https://colab.research.google.com/github/Derrick-Tan-D-WEBDEV/Data-Analysis-with-python/blob/main/data_analysis_with_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Numpy
# ![numpylogo_-_gabe_perez-giz.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Basic Numpy Arrays

# %% [markdown]
# 👉Print an array like python list, but using numpy will be faster compare to normal python's list!

# %%
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %% [markdown]
# 👉Printing numpy array

# %%
a = np.array([1,2,3,4])
b = np.array ([0,.5,1,1.5,2])
print(a[0],a[1])
# Out:
# 1 2

# %% [markdown]
# 👉Printing numpy array (another method) but it will turn into a tuple

# %%
a[0],a[1]
# Out:
# (1, 2)

# %%
a[0:2]
# Out:
# array([1, 2])

# %%
a[0:]
# Out:
# array([1, 2, 3, 4])

# %% [markdown]
# # New Section

# %%
import requests
import pandas as pd
